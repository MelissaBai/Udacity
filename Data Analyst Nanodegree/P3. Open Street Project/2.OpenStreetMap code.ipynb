# %% [markdown]
# # Clean Open Street Map in Palo Alto Area

# %% [markdown]
# <h2> Brief Overview </h2>
#
# <p>Audit and clean the dataset of Palo Alto area from OpenStreetMap, converting it from XML to JSON format. Then, import the clean JSON file into a MongoDB database and run some queries against it.</p>

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint
import json
import codecs

# %%
osm_file = open("OpenStreetMap.osm", "r")

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
zipcode = re.compile(r'\d{5}(?:-\d{4})?')
#zip_types = defaultdict(set)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court",
           "Place", "Parkway", "Path", "Pass", "Circle", "Road",
           "Road", "Way", "Lane", "Mall"]

mapping = {"Dr.": "Drive",
           "St": "Street",
           "Ave": "Avenue",
           "Rd": "Road",
           "avenue": "Avenue"}

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
def audit_zip_type(zip_types, postal):
    z = zipcode.search(postal)
    if z:
        zip_types['normal'].add(postal)
    else:
        zip_types['non_normal'].add(postal)
        
        
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_zip(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_street_name(osm_file):
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types
    #pprint.pprint(dict(street_types))

def update_name(name, mapping):
    name_list = name.split(" ")
    suffix = name_list[-1]
    if suffix in mapping:
        new_suffix = mapping[suffix]
        name_list[-1] = new_suffix
    name = " ".join(name_list)
    return name

def audit_zipcode_name():
    zip_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zip(tag):
                    audit_zip_type(zip_types, tag.attrib['v'])
    pprint.pprint(dict(zip_types))
    
def better_name():
    st_types = audit_street_name(osm_file)
    #pprint.pprint(dict(st_types))
    
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            name = better_name
            print name, "=>", better_name

#better_name()

#audit_street_name()
audit_zipcode_name()
# Out:
# {'normal': set(['94025',
#                 '94036',
#                 '94301',
#                 '94301-2019',
#                 '94303',
#                 '94304',
#                 '94304-1050',
#                 '94305',
#                 '94305-6015',
#                 '94305;94309',
#                 '94306'])}

# %%
# Convert into json file
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
POS = ['lat', 'lon']
#elem_dict = defaultdict(list)

def shape_element(element):
    #node = defaultdict()
    node = {}
    if element.tag == "node" or element.tag == "way":
        for subelement in element:
            if 'k' in subelement.attrib:
                if re.search(problemchars, subelement.attrib['k']):
                    pass
                elif subelement.attrib['k'].count(":")>1:
                    pass
                elif subelement.attrib['k'].startswith("addr:") and subelement.attrib['k'].count(":")==1:
                    if 'address' not in node: 
                        node['address'] = {}
             
                    name = subelement.attrib['k'].split(":")[1]
                    node['address'][name] = subelement.attrib['v']
                    #print node
                elif not subelement.attrib['k'].startswith("addr:"):
                    node[subelement.attrib['k']] = subelement.attrib['v']
            if 'ref' in subelement.attrib:
                if 'node_refs' not in node:
                    node['node_refs'] = []
                node['node_refs'].append(subelement.attrib['ref'])
                        
        node['type'] = element.tag
        created = {}
        if element.tag == 'node':
            node['pos'] = extract_pos(element)
        for elem in element.attrib.keys():
            if elem in CREATED:
                created[elem] = element.attrib[elem]
                node['created'] = created
            elif elem in POS:
                continue
            else:
                node[elem] = element.attrib[elem]
        print node        
        return node
    else:
        return None

def extract_pos(element):
    try:
        return [float(element.attrib['lat']),  float(element.attrib['lon'])]
    except (ValueError, KeyError):
        print 'Failed to parse position ...'
    return None
    
"""
def extract_pos(element):
    lat, lon = None, None
    try:
        lat = float(element.attrib['lat'])
    except:
        print 'Could not parse lat as float', element.attrib['lat']
    try:
        lon = float(element.attrib['lon'])
    except:
        print 'Could not parse lon as float', element.attrib['lon']
    pos = []
    if lat:
        pos.append(lat)
    if lon:
        pos.append(lon)
    return pos
"""

def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

 'created': {'changeset': '2962562', 'user': 'Speight', 'version': '1', 'uid': '24452', 'timestamp': '2009-10-27T04:22:57Z'}}
# {'id': '541336418', 'type': 'node', 'pos': [37.442936, -122.1662223], 'created': {'changeset': '5414094', 'user': 'KindredCoda', 'version': '2', 'uid': '14293', 'timestamp': '2010-08-06T06:54:39Z'}}
# {'id': '541336419', 'type': 'node', 'pos': [37.4432557, -122.1666978], 'created': {'changeset': '2962562', 'user': 'Speight', 'version': '1', 'uid': '24452', 'timestamp': '2009-10-27T04:23:45Z'}}
# {'id': '541336420', 'type': 'node', 'pos': [37.4434806, -122.1670154], 'created': {'changeset': '2962562', 'user': 'Speight', 'version': '1', 'uid': '24452', 'timestamp': '2009-10-27T04:23:45Z'}}
# {'id': '541336421', 'type': 'node', 'pos': [37.4436541, -122.1672687], 'created': {'changeset': '9272851', 'user': 'oldtopos', 'version': '2', 'uid': '169004', 'timestamp': '2011-09-11T17:18:54Z'}}
# {'id': '541336423', 'type': 'node', 'pos': [37.4438073, -122.1674714], 'created': {'changeset': '9272851', 'user': 'oldtopos', 'version': '3', 'uid': '169004', 'timestamp': '2011-09-11T17:18:54Z'}}
# {'id': '541336424', 'type': 'node', 'pos': [37.444072, -122.167919], 'created': {'changeset': '11944094', 'user': 'oldtopos', 'version': '6', 'uid': '169004', 'timestamp': '2012-06-19T05:30:42Z'}}
# {'id': '548051334', 'type': 'node', 'pos': [37.438386, -122.173576], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:53Z'}}
# {'id': '548051348', 'type': 'node', 'pos': [37.438477, -122.174022], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:53Z'}}
# {'id': '548051362', 'type': 'node', 'pos': [37.439456, -122.173833], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:54Z'}}
# {'id': '548051377', 'type': 'node', 'pos': [37.439116, -122.173805], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:54Z'}}
# {'id': '548051396', 'type': 'node', 'pos': [37.439489, -122.173742], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:55Z'}}
# {'id': '548051417', 'type': 'node', 'pos': [37.439434, -122.173563], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:56Z'}}
# {'id': '548051422', 'type': 'node', 'pos': [37.439289, -122.173889], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:57Z'}}
# {'id': '548051426', 'type': 'node', 'pos': [37.438188, -122.172606], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:58Z'}}
# {'id': '548051431', 'type': 'node', 'pos': [37.439339, -122.173076], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:58Z'}}
# {'id': '548051434', 'type': 'node', 'pos': [37.439367, -122.173398], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:07:59Z'}}
# {'id': '548051437', 'type': 'node', 'pos': [37.439072, -122.172999], 'created': {'changeset': '2995270', 'user': 'nmixter', 'version': '1', 'uid': '55774', 'timestamp': '2009-10-31T09:08:00Z'}}

# %%
# Separate block of function
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        key = element.attrib['k']
        #print key
        if lower.search(key):
            keys['lower'] += 1
        elif lower_colon.search(key):
            keys['lower_colon'] += 1
        elif problemchars.search(key):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
            print key
        
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


def main():
    keys = process_map('OpenStreetMap.osm')
    pprint.pprint(keys)

#main()
# Out:
# COUNTYFP
# STATEFP
# Tiger:MTFCC
# COUNTYFP
# STATEFP
# Tiger:MTFCC
# gnis:Class
# gnis:County
# gnis:County_num
# gnis:ST_alpha
# gnis:ST_num
# gnis:Class
# gnis:County
# gnis:County_num
# gnis:ST_alpha
# gnis:ST_num
# gnis:Class
# gnis:County
# gnis:County_num
# gnis:ST_alpha
# gnis:ST_num
# gnis:Class
# gnis:County
# gnis:County_num
# gnis:ST_alpha
# gnis:ST_num
# gnis:Class
# gnis:County
# gnis:County_num
# gnis:ST_alpha
# gnis:ST_num
# FIXME
# name2
# addr:1:housenumber
# service:bicycle:chain_tool
# socket:type1
# source:hgv:national_network
# turn:lanes:forward
# name_1
# tiger:name_base_1
# tiger:name_type_1
# tiger:zip_left_1
# tiger:zip_left_2
# turn:lanes:backward
# tiger:zip_left_1
# tiger:zip_right_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# tiger:zip_left_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# tiger:name_base_1
# tiger:zip_left_1
# name_1
# turn:lanes:forward
# tiger:zip_left_1
# tiger:zip_left_2
# tiger:zip_right_1
# tiger:zip_right_2
# name_1
# tiger:name_base_1
# tiger:name_type_1
# tiger:zip_left_1
# tiger:zip_left_2
# name_1
# tiger:name_base_1
# tiger:name_type_1
# turn:lanes:backward
# tiger:name_base_1
# NHS
# source:hgv:national_network
# turn:lanes:forward
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# turn:lanes:backward
# tiger:zip_left_1
# is_in:iso_3166_2
# tiger:CLASSFP
# tiger:CPI
# tiger:FUNCSTAT
# tiger:LSAD
# tiger:MTFCC
# tiger:NAME
# tiger:NAMELSAD
# tiger:PCICBSA
# tiger:PCINECTA
# tiger:PLACEFP
# tiger:PLACENS
# tiger:PLCIDFP
# tiger:STATEFP
# ALAND
# AREAID
# AWATER
# COUNTYFP
# MTFCC
# STATEFP
# Tiger:MTFCC
# ALAND
# AREAID
# AWATER
# COUNTYFP
# MTFCC
# STATEFP
# Tiger:MTFCC
# ALAND
# AREAID
# AWATER
# COUNTYFP
# MTFCC
# STATEFP
# Tiger:MTFCC
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:FACILITY
# scvwd:ROUTEID
# scvwd:SHAPE_AREA
# scvwd:WB_TYPE
# change:lanes:backward
# change:lanes:forward
# turn:lanes:backward
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# name_1
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# tiger:LINEARID
# tiger:MTFCC
# destination:street:to
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# FIXME
# amenity_1
# name_1
# source:hgv:national_network
# turn:lanes:backward
# tiger:zip_left_1
# tiger:zip_left_1
# tiger:zip_left_1
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# name_1
# name_1
# FIXME
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:2:housenumber
# addr:2:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:5:housenumber
# addr:6:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:5:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:5:housenumber
# addr:6:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:street
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:street
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:street
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:street
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:street
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:4:street
# addr:5:housenumber
# addr:5:street
# name_1
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:2:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# addr:1:housenumber
# source:hgv:national_network
# tiger:name_base_1
# name_1
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:forward
# turn:lanes:forward
# source:hgv:national_network
# tiger:name_base_1
# NHS
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# source:hgv:national_network
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# source:hgv:national_network
# turn:lanes:forward
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# turn:lanes:backward
# turn:lanes:forward
# change:lanes:backward
# change:lanes:forward
# turn:lanes:forward
# change:lanes:backward
# change:lanes:forward
# turn:lanes:backward
# source:hgv:national_network
# name_1
# tiger:name_base_1
# tiger:name_type_1
# name_1
# tiger:name_base_1
# tiger:name_type_1
# turn:lanes:backward
# turn:lanes:backward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:forward
# turn:lanes:forward
# source:hgv:national_network
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# tiger:name_base_1
# turn:lanes:backward
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# source:hgv:national_network
# tiger:name_base_1
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:forward
# turn:lanes:backward
# turn:lanes:backward
# NHS
# NHS
# scvwd:OBJECTID
# scvwd:SHAPE_AREA
# is_in:iso_3166_2
# is_in:iso_3166_2
# COUNTYFP
# STATEFP
# Tiger:MTFCC
# addr:1:housenumber
# addr:2:housenumber
# addr:3:housenumber
# addr:4:housenumber
# addr:5:housenumber
# addr:1:housenumber
# addr:1:housenumber
# {'lower': 56836, 'lower_colon': 69902, 'other': 620, 'problemchars': 0}
